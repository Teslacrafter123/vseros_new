# %%
import featuretools as ft
import seaborn as sns

# %%
df = sns.load_dataset('penguins')

# %%
es = ft.EntitySet(id='penguins_dataframe')

# %%
df.dropna(inplace=True)
df = df.reset_index()

# %%
es = es.add_dataframe(dataframe=df, dataframe_name='penguins')
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\featuretools\entityset\entityset.py:1717: UserWarning: Using first column as index. To change this, specify the index parameter
#   warnings.warn(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\woodwork\type_sys\utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\woodwork\type_sys\utils.py:33: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(
# ...

# %%
feature_matrix, feature_defs = ft.dfs(
    entityset=es,
    target_dataframe_name="penguins",
    max_depth=1,
)
feature_matrix.head()
# Out:
#       species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# index
# 0      Adelie  Torgersen            39.1           18.7              181.0
# 1      Adelie  Torgersen            39.5           17.4              186.0
# 2      Adelie  Torgersen            40.3           18.0              195.0
# 4      Adelie  Torgersen            36.7           19.3              193.0
# 5      Adelie  Torgersen            39.3           20.6              190.0
#
#        body_mass_g     sex
# index
# 0           3750.0    Male
# 1           3800.0  Female
# 2           3250.0  Female
# 4           3450.0  Female
# 5           3650.0    Male

# %%
ft.selection.remove_highly_null_features(feature_matrix)
# Out:
#       species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# index
# 0      Adelie  Torgersen            39.1           18.7              181.0
# 1      Adelie  Torgersen            39.5           17.4              186.0
# 2      Adelie  Torgersen            40.3           18.0              195.0
# 4      Adelie  Torgersen            36.7           19.3              193.0
# 5      Adelie  Torgersen            39.3           20.6              190.0
# ...       ...        ...             ...            ...                ...
# 338    Gentoo     Biscoe            47.2           13.7              214.0
# 340    Gentoo     Biscoe            46.8           14.3              215.0
# 341    Gentoo     Biscoe            50.4           15.7              222.0
# 342    Gentoo     Biscoe            45.2           14.8              212.0
# 343    Gentoo     Biscoe            49.9           16.1              213.0
#
#        body_mass_g     sex
# index
# ...

# %%
ft.selection.remove_single_value_features(feature_matrix)
# Out:
#       species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# index
# 0      Adelie  Torgersen            39.1           18.7              181.0
# 1      Adelie  Torgersen            39.5           17.4              186.0
# 2      Adelie  Torgersen            40.3           18.0              195.0
# 4      Adelie  Torgersen            36.7           19.3              193.0
# 5      Adelie  Torgersen            39.3           20.6              190.0
# ...       ...        ...             ...            ...                ...
# 338    Gentoo     Biscoe            47.2           13.7              214.0
# 340    Gentoo     Biscoe            46.8           14.3              215.0
# 341    Gentoo     Biscoe            50.4           15.7              222.0
# 342    Gentoo     Biscoe            45.2           14.8              212.0
# 343    Gentoo     Biscoe            49.9           16.1              213.0
#
#        body_mass_g     sex
# index
# ...

# %%
ft.selection.remove_highly_correlated_features(feature_matrix)
# Out:
#       species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# index
# 0      Adelie  Torgersen            39.1           18.7              181.0
# 1      Adelie  Torgersen            39.5           17.4              186.0
# 2      Adelie  Torgersen            40.3           18.0              195.0
# 4      Adelie  Torgersen            36.7           19.3              193.0
# 5      Adelie  Torgersen            39.3           20.6              190.0
# ...       ...        ...             ...            ...                ...
# 338    Gentoo     Biscoe            47.2           13.7              214.0
# 340    Gentoo     Biscoe            46.8           14.3              215.0
# 341    Gentoo     Biscoe            50.4           15.7              222.0
# 342    Gentoo     Biscoe            45.2           14.8              212.0
# 343    Gentoo     Biscoe            49.9           16.1              213.0
#
#        body_mass_g     sex
# index
# ...

# %%
import geopandas as gpd
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing(as_frame=True).data
df['point'] = gpd.points_from_xy(df['Latitude'], df['Longitude'])

# %%
df = gpd.GeoDataFrame(
        df,
        geometry=gpd.points_from_xy(df['Longitude'], df['Latitude']),
        crs=4326
    ).to_crs(epsg=3857)

# %%
import requests, zipfile, io

# %%
county_fname = 'https://github.com/a-milenkin/Competitive_Data_Science/raw/main/data/ca-county-boundaries.zip'

r2 = requests.get(county_fname)
z2 = zipfile.ZipFile(io.BytesIO(r2.content))
z2.extractall("./ca")

# %%
ca_counties=gpd.read_file('./ca/CA_Counties').to_crs("EPSG:3857")
ca_counties.head(3)
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD LSAD  \
# 0      06      091  00277310  06091         Sierra         Sierra County   06
# 1      06      067  00277298  06067     Sacramento     Sacramento County   06
# 2      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
#
#   CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND      AWATER  \
# 0      H1  G4020  None   None     None        A  2468694587    23299110
# 1      H1  G4020   472  40900     None        A  2499183617    76073827
# 2      H1  G4020  None  42200     None        A  7084000598  2729814515
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# 1  +38.4500114  -121.3404409
# 2  +34.5370572  -120.0399729
#
#                                             geometry
# 0  POLYGON ((-13431319.751 4821511.426, -13431312...
# 1  POLYGON ((-13490651.476 4680831.603, -13490511...
# 2  MULTIPOLYGON (((-13423116.772 4042044.149, -13...

# %%
gdf = gpd.overlay(df, ca_counties[['NAME', 'geometry']], how='intersection')

# %%
gdf
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20632  3.7574      33.0  6.135678   1.185930       488.0  2.452261     38.90
# 20633  3.8750      31.0  4.416667   0.880952       208.0  2.476190     38.73
# 20634  3.3472      19.0  5.802752   1.045872       755.0  3.463303     38.65
# 20635  3.0486      26.0  4.756410   0.948718       689.0  2.944444     38.68
# 20636  2.7955      23.0  5.442424   1.151515       939.0  2.845455     38.69
#
# ...

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, \
    load_robot_execution_failures

download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()
timeseries
# Out:
#       id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0      1     0   -1   -1   63   -3   -1    0
# 1      1     1    0    0   62   -3   -1    0
# 2      1     2   -1   -1   61   -3    0    0
# 3      1     3   -1   -1   63   -2   -1    0
# 4      1     4   -1   -1   63   -3   -1    0
# ...   ..   ...  ...  ...  ...  ...  ...  ...
# 1315  88    10  -10    2   39  -21  -24    5
# 1316  88    11  -11    2   38  -24  -22    6
# 1317  88    12  -12    3   23  -24  -24    5
# 1318  88    13  -13    4   26  -29  -27    5
# 1319  88    14  -13    2   15  -25  -25    6
#
# [1320 rows x 8 columns]

# %%
from tsfresh.feature_extraction import MinimalFCParameters
from pprint import pprint

pprint(MinimalFCParameters())
# Out:
# {'absolute_maximum': None,
#  'length': None,
#  'maximum': None,
#  'mean': None,
#  'median': None,
#  'minimum': None,
#  'root_mean_square': None,
#  'standard_deviation': None,
#  'sum_values': None,
#  'variance': None}

# %%
from tsfresh import extract_features

extracted_features = extract_features(timeseries, column_id="id", column_sort="time", n_jobs=2, default_fc_parameters=MinimalFCParameters())
extracted_features.head()
# Out:
# Feature Extraction: 100%|██████████| 10/10 [00:03<00:00,  3.01it/s]
#    F_x__sum_values  F_x__median  F_x__mean  F_x__length  \
# 1            -14.0         -1.0  -0.933333         15.0
# 2            -13.0         -1.0  -0.866667         15.0
# 3            -10.0         -1.0  -0.666667         15.0
# 4             -6.0          0.0  -0.400000         15.0
# 5             -9.0         -1.0  -0.600000         15.0
#
#    F_x__standard_deviation  F_x__variance  F_x__root_mean_square  \
# 1                 0.249444       0.062222               0.966092
# 2                 0.956847       0.915556               1.290994
# 3                 0.596285       0.355556               0.894427
# 4                 0.952190       0.906667               1.032796
# 5                 0.879394       0.773333               1.064581
#
#    F_x__maximum  F_x__absolute_maximum  F_x__minimum  ...  T_z__sum_values  \
# 1           0.0                    1.0          -1.0  ...              0.0
# ...
