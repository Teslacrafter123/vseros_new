# %% [markdown]
# https://github.com/a-milenkin/Competitive_Data_Science/blob/main/notebooks/6.3%20-%20Automatic%20Stacking.ipynb

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'meta_feautres_data.csv')

# %%
df = pd.read_csv(r'meta_feautres_data.csv')
df = df.pivot_table('target', 'index', 'model').reset_index().drop('index', axis=1)[['catboost', 'lgbm', 'xgb']]
lst = df.columns.tolist()
for i in lst:
    for u in lst:
        df[f'{i}_dif_{u}'] = df[i] - df[u]
        df[f'{i}_div_{u}'] = df[i] / df[u]
df = df.reset_index()

# %%
df
# Out:
#       index     target     model
# 0         0  65.927922  catboost
# 1         1  44.248116  catboost
# 2         2  43.807966  catboost
# 3         3  45.661121  catboost
# 4         4  43.653036  catboost
# ...     ...        ...       ...
# 1750    580  39.795555       xgb
# 1751    581  42.351254       xgb
# 1752    582  44.074200       xgb
# 1753    583  40.630420       xgb
# 1754    584  43.850530       xgb
#
# [1755 rows x 3 columns]

# %%
new = df.rename(columns={'catboost': 'target_catboost', 'lgbm': 'lgbm_catboost', 'xgb': 'target_xgb'}).to_csv(r'ans.csv', index=False)

# %%
new = df.rename(columns={'catboost': 'target_catboost', 'lgbm': 'lgbm_catboost', 'xgb': 'target_xgb'})

# %%
new
# Out:
# model  index  target_catboost  lgbm_catboost  target_xgb  \
# 0          0        65.927922      49.622930   55.741352
# 1          1        44.248116      43.244205   42.661655
# 2          2        43.807966      45.389293   42.217470
# 3          3        45.661121      44.769051   40.969734
# 4          4        43.653036      40.462658   38.243040
# ..       ...              ...            ...         ...
# 580      580        43.372847      44.205443   39.795555
# 581      581        44.168977      42.959736   42.351254
# 582      582        44.393186      43.844842   44.074200
# 583      583        43.649487      46.200331   40.630420
# 584      584        44.128439      45.071626   43.850530
#
# model  catboost_dif_catboost  catboost_div_catboost  catboost_dif_lgbm  \
# 0                        0.0                    1.0          16.304993
# 1                        0.0                    1.0           1.003911
# ...
