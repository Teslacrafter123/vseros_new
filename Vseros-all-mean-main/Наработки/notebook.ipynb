# %%
from feature_engine.imputation import MeanMedianImputer
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import KFold
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import roc_auc_score, roc_curve, f1_score, precision_score, recall_score, accuracy_score
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LogisticRegression

from tqdm import tqdm_notebook
import tqdm
import warnings
from sklearn.exceptions import ConvergenceWarning
import matplotlib.pyplot as plt
import seaborn as sns
import shap

warnings.simplefilter('ignore')
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
seed = 22
np.random.seed(seed)

# %%
df = pd.read_csv(r'train.tsv', sep='\t', index_col=0)

# %%
df = df.replace('?', np.nan)

# %%
X = df.drop(columns=['y']).astype(float)
cols = X.columns.tolist()

# %%
imp = MeanMedianImputer(imputation_method='median')
imp.fit(X)
# Out:
# MeanMedianImputer()

# %%
X = imp.transform(X)

# %%
dct_to = {'N': 0, 'P': 1}
dct_out = {0: 'N', 1: 'P'}
y = df['y']
y = y.map(dct_to)

# %%
crs_late = X.corrwith(y).sort_values(ascending=False, key=abs)

# %%
for x in crs_late[abs(crs_late) > 0.3].index.tolist():
    for x2 in crs_late[abs(crs_late) > 0.3].index.tolist():
        if x != x2:
            X[f'{x}_div_{x2}'] = X[x] / X[x2]

# %%
crs = X.drop(columns=cols).corrwith(y).sort_values(ascending=False, key=abs)

# %%
good_divs = crs[abs(crs) > 0.45].index.tolist()
len(good_divs)
# Out:
# 107

# %%
X = X[cols + good_divs]

# %%
X
# Out:
#          x1    x2    x3    x4    x5     x6     x7     x8     x9   x10  ...  \
# id                                                                     ...
# 1      80.0  60.0 -10.0 -20.0 -10.0  150.0  350.0 -510.0   60.0 -10.0  ...
# 2      70.0  20.0 -20.0 -10.0 -10.0  140.0  360.0 -440.0 -400.0   0.0  ...
# 3      80.0  60.0  20.0 -10.0  10.0  140.0  190.0 -500.0  880.0   0.0  ...
# 4      60.0  60.0  10.0 -40.0   0.0  140.0  580.0 -450.0 -200.0 -10.0  ...
# 5      70.0  60.0  10.0 -10.0   0.0  230.0  350.0   30.0  390.0   0.0  ...
# ...     ...   ...   ...   ...   ...    ...    ...    ...    ...   ...  ...
# 19996  70.0  80.0  10.0   0.0   0.0  180.0  180.0 -600.0  590.0   0.0  ...
# 19997  70.0  90.0  10.0   0.0   0.0  140.0  540.0 -380.0   60.0 -10.0  ...
# 19998  60.0  60.0  10.0  40.0  10.0  180.0  320.0 -450.0   60.0   0.0  ...
# 19999  70.0  60.0 -30.0   0.0   0.0  200.0  300.0 -450.0   60.0   0.0  ...
# 20000  80.0  70.0  10.0 -20.0   0.0  130.0  660.0 -190.0 -400.0   0.0  ...
#
#        x736_div_x291  x186_div_x650  x147_div_x444  x890_div_x836  \
# id
# 1           0.984848       0.342593      -0.530435       0.503663
# 2           0.429752       0.390244      -0.391304       0.471287
# 3           0.571429       0.330623      -0.394322       0.544554
# 4           0.559633       0.304239      -0.462733       0.544554
# 5           0.355372       0.386091      -0.449351       0.823762
# ...              ...            ...            ...            ...
# 19996       0.368794       0.287736      -0.391304       0.718812
# 19997       0.454545       0.192857      -0.257143       0.574113
# 19998       0.419355       0.342697      -0.271540       0.554455
# 19999       0.241135       0.330623      -0.315068       0.726733
# 20000       0.429752       0.468586      -0.491639       0.467687
#
#        x736_div_x650  x147_div_x789  x600_div_x229  x215_div_x147  \
# id
# 1          -0.150463      -1.095808       2.213115      -0.540984
# 2          -0.140921      -0.754491       1.730769      -1.007937
# 3          -0.184282      -0.698324       1.200000      -1.192000
# 4          -0.152120      -0.892216       1.831461      -0.751678
# 5          -0.103118      -1.362205       1.483516      -0.433526
# ...              ...            ...            ...            ...
# 19996      -0.122642      -0.659686       1.730769      -1.103175
# 19997      -0.098214      -0.664773       1.516854      -1.487179
# 19998      -0.146067      -0.601156       1.258427      -1.519231
# 19999      -0.092141      -0.575000       1.000000      -1.121739
# 20000      -0.136126      -1.027972       2.045872      -0.639456
#
#        x186_div_x215  x491_div_x759
# id
# 1          -1.494949       0.297003
# 2          -1.133858       0.149100
# 3          -0.818792       0.055556
# 4          -1.089286       0.206406
# 5          -2.146667       0.293548
# ...              ...            ...
# 19996      -0.877698       0.149100
# 19997      -0.620690       0.113111
# 19998      -0.772152       0.123667
# 19999      -0.945736       0.141463
# 20000      -1.904255       0.146530
#
# [20000 rows x 1107 columns]

# %%
from collections import Counter

for x in Counter(X.columns):
    if Counter(X.columns)[x] > 1:
        print(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, stratify=y)

# %%
rfc = RandomForestClassifier(random_state=seed)
rfc.fit(X_train, y_train)

cat = CatBoostClassifier(use_best_model=True, random_state=seed, verbose=500)
cat.fit(X_train, y_train, eval_set=(X_test, y_test))

xgb = XGBClassifier(random_state=seed)
xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=10)

lgbm = LGBMClassifier(random_state=seed, verbose=-1)
lgbm.fit(X_train, y_train, eval_set=[(X_test, y_test)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[150], line 2
#       1 rfc = RandomForestClassifier(random_state=seed)
# ----> 2 rfc.fit(X_train, y_train)
#       4 cat = CatBoostClassifier(use_best_model=True, random_state=seed, verbose=500)
#       5 cat.fit(X_train, y_train, eval_set=(X_test, y_test))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
df_imp = pd.DataFrame()
df_imp['cols'] = X.columns
df_imp['Rfc_imp'] = rfc.feature_importances_
df_imp['Cat_imp'] = cat.feature_importances_
df_imp['XGB_imp'] = xgb.feature_importances_
df_imp['LGBM_imp'] = lgbm.feature_importances_

# %%
rfc_rank = df_imp[['Rfc_imp', 'cols']].sort_values(by='Rfc_imp', ascending=False).reset_index(drop=True).reset_index()
rfc_rank = rfc_rank.rename(columns={'index': 'rfc_ind'})
rfc_rank['rfc_ind'] += 1
df_imp = df_imp.merge(rfc_rank)

# %%
cat_rank = df_imp[['Cat_imp', 'cols']].sort_values(by='Cat_imp', ascending=False).reset_index(drop=True).reset_index()
cat_rank = cat_rank.rename(columns={'index': 'cat_ind'})
cat_rank['cat_ind'] += 1
df_imp = df_imp.merge(cat_rank)

# %%
XGB_rank = df_imp[['XGB_imp', 'cols']].sort_values(by='XGB_imp', ascending=False).reset_index(drop=True).reset_index()
XGB_rank = XGB_rank.rename(columns={'index': 'XGB_ind'})
XGB_rank['XGB_ind'] += 1
df_imp = df_imp.merge(XGB_rank)

# %%
LGBM_rank = df_imp[['LGBM_imp', 'cols']].sort_values(by='LGBM_imp', ascending=False).reset_index(drop=True).reset_index()
LGBM_rank = LGBM_rank.rename(columns={'index': 'LGBM_ind'})
LGBM_rank['LGBM_ind'] += 1
df_imp = df_imp.merge(LGBM_rank)

# %%
print(f1_score(y_test, rfc.predict(X_test)))
print(f1_score(y_test, cat.predict(X_test)))
print(f1_score(y_test, xgb.predict(X_test)))
print(f1_score(y_test, lgbm.predict(X_test)))
# Out:
# 0.8588132125109617
# 0.8732718894009217
# 0.8666281755196305
# 0.8677065280184865

# %%
result = permutation_importance(cat, X, y, n_repeats=2, random_state=seed)

# %%
df_imp['perm_imp'] = result.importances_mean

# %%
perm_rank = df_imp[['perm_imp', 'cols']].sort_values(by='perm_imp', ascending=False).reset_index(drop=True).reset_index()
perm_rank = perm_rank.rename(columns={'index': 'perm_ind'})
perm_rank['perm_ind'] += 1
df_imp = df_imp.merge(perm_rank)

# %%
df_imp
# Out:
#                cols   Rfc_imp   Cat_imp   XGB_imp  LGBM_imp  rfc_ind  cat_ind  \
# 0                x1  0.000051  0.000000  0.000934         0     1060      918
# 1                x2  0.000284  0.010964  0.000321         1      726      792
# 2                x3  0.000326  0.035787  0.000183         5      678      563
# 3                x4  0.000359  0.090118  0.000559         4      628      314
# 4                x5  0.000125  0.006916  0.000409         0      922      830
# ...             ...       ...       ...       ...       ...      ...      ...
# 1102  x147_div_x789  0.000539  0.100510  0.000379         3      403      282
# 1103  x600_div_x229  0.003185  0.259524  0.000502         4       65      104
# 1104  x215_div_x147  0.000722  0.051212  0.002722         2      254      473
# 1105  x186_div_x215  0.001035  0.086891  0.000217         2      181      323
# 1106  x491_div_x759  0.001509  0.000000  0.003159         2      127     1107
#
#       XGB_ind  LGBM_ind  perm_imp  perm_ind
# 0         132       854  0.000000       665
# 1         595       764  0.000000       833
# 2         782       171  0.000075       368
# 3         312       269  0.000325        47
# 4         467       948  0.000000       759
# ...       ...       ...       ...       ...
# 1102      513       369  0.000125       204
# 1103      367       266 -0.000025       894
# 1104       27       549  0.000025       485
# 1105      746       538 -0.000150      1062
# 1106       23       448  0.000000       810
#
# [1107 rows x 11 columns]

# %%
model_lr = LogisticRegression(random_state=seed)
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=22)

# %%
explainer = shap.LinearExplainer(model_lr, shap.maskers.Independent(X_train))
shap_values = explainer(X_test)

feature_names = X_train.columns


rf_resultX = pd.DataFrame(shap_values.values, columns=feature_names)


vals = np.abs(rf_resultX.values).mean(0)

shap_importance = pd.DataFrame(list(zip(feature_names, vals)),
                                  columns=['cols','shap_imp'])
shap_importance.sort_values(by=['shap_imp'],
                               ascending=False, inplace=True)

# %%
shap_importance = shap_importance.sort_values(by='shap_imp', ascending=False).reset_index(drop=True).reset_index()
shap_importance = shap_importance.rename(columns={'index': 'shap_ind'})
shap_importance['shap_ind'] += 1
df_imp = df_imp.merge(shap_importance)

# %%
df_imp
# Out:
#                cols   Rfc_imp   Cat_imp   XGB_imp  LGBM_imp  rfc_ind  cat_ind  \
# 0                x1  0.000051  0.000000  0.000934         0     1060      918
# 1                x2  0.000284  0.010964  0.000321         1      726      792
# 2                x3  0.000326  0.035787  0.000183         5      678      563
# 3                x4  0.000359  0.090118  0.000559         4      628      314
# 4                x5  0.000125  0.006916  0.000409         0      922      830
# ...             ...       ...       ...       ...       ...      ...      ...
# 1102  x147_div_x789  0.000539  0.100510  0.000379         3      403      282
# 1103  x600_div_x229  0.003185  0.259524  0.000502         4       65      104
# 1104  x215_div_x147  0.000722  0.051212  0.002722         2      254      473
# 1105  x186_div_x215  0.001035  0.086891  0.000217         2      181      323
# 1106  x491_div_x759  0.001509  0.000000  0.003159         2      127     1107
#
#       XGB_ind  LGBM_ind  perm_imp  perm_ind  shap_ind      shap_imp
# 0         132       854  0.000000       665       740  1.960952e-04
# 1         595       764  0.000000       833       554  1.346673e-03
# 2         782       171  0.000075       368       598  7.958523e-04
# 3         312       269  0.000325        47       513  2.220906e-03
# 4         467       948  0.000000       759       755  1.603133e-04
# ...       ...       ...       ...       ...       ...           ...
# 1102      513       369  0.000125       204      1028  7.885571e-08
# 1103      367       266 -0.000025       894      1014  3.235404e-07
# 1104       27       549  0.000025       485      1032  5.689607e-08
# 1105      746       538 -0.000150      1062      1070  1.370802e-08
# 1106       23       448  0.000000       810      1072  1.066631e-08
#
# [1107 rows x 13 columns]

# %%
df_imp['full_imp'] = df_imp['rfc_ind'] + df_imp['cat_ind'] + df_imp['XGB_ind'] + df_imp['LGBM_ind'] + df_imp['perm_ind'] + df_imp['shap_ind']

# %%
final_cols = df_imp.sort_values(by='full_imp').head(200)['cols'].tolist()

# %%
X_new = X[final_cols]

# %%
final_cols
# Out:
# ['x22',
#  'x742',
#  'x144',
#  'x729',
#  'x202',
#  'x191',
#  'x53',
#  'x375',
#  'x88',
#  'x169',
#  'x308',
#  'x879',
#  'x526',
#  'x969',
#  'x763',
#  'x704',
#  'x597',
#  'x478',
#  'x101',
#  'x867',
#  'x183',
#  'x942',
#  'x670',
#  'x419',
#  'x861',
#  'x630',
#  'x391',
#  'x326',
#  'x796',
#  'x658',
#  'x900',
#  'x193',
#  'x536',
#  'x63',
#  'x706',
#  'x286',
#  'x552',
#  'x882',
#  'x218',
#  'x331',
#  'x492',
#  'x341',
#  'x281',
#  'x525',
#  'x288',
#  'x741',
#  'x223',
#  'x538',
#  'x908',
#  'x877',
#  'x175',
#  'x439',
#  'x203',
#  'x562',
#  'x846',
#  'x641',
#  'x576',
#  'x469',
#  'x588',
#  'x769',
#  'x607',
#  'x600_div_x890',
#  'x232',
#  'x836',
#  'x783',
#  'x886',
#  'x598',
#  'x902',
#  'x601',
#  'x227',
#  'x466',
#  'x836_div_x227',
#  'x866',
#  'x236',
#  'x818',
#  'x176',
#  'x327',
#  'x82',
#  'x407',
#  'x836_div_x890',
#  'x353',
#  'x231',
#  'x746',
#  'x233',
#  'x502',
#  'x215',
#  'x453',
#  'x657',
#  'x258',
#  'x42',
#  'x744',
#  'x399',
#  'x287',
#  'x656',
#  'x546',
#  'x785',
#  'x943',
#  'x884',
#  'x234',
#  'x443',
#  'x291',
#  'x563',
#  'x539',
#  'x694',
#  'x294',
#  'x543',
#  'x890',
#  'x695',
#  'x364',
#  'x410',
#  'x573',
#  'x444',
#  'x241',
#  'x134',
#  'x897',
#  'x437',
#  'x672',
#  'x337',
#  'x75',
#  'x253',
#  'x199',
#  'x624',
#  'x919',
#  'x184',
#  'x181',
#  'x398',
#  'x457',
#  'x651',
#  'x978',
#  'x691',
#  'x310',
#  'x442',
#  'x282',
#  'x340',
#  'x948',
#  'x583',
#  'x81',
#  'x216',
#  'x605',
#  'x347',
#  'x779',
#  'x759',
#  'x491_div_x419',
#  'x578',
#  'x6',
#  'x489',
#  'x994',
#  'x491_div_x789',
#  'x260',
#  'x244',
#  'x357',
#  'x229',
#  'x739',
#  'x850',
#  'x80',
#  'x960',
#  'x200',
#  'x600_div_x693',
#  'x378',
#  'x449',
#  'x464',
#  'x452',
#  'x777',
#  'x808',
#  'x774',
#  'x890_div_x147',
#  'x569',
#  'x845',
#  'x663',
#  'x531',
#  'x951',
#  'x574_div_x444',
#  'x498',
#  'x491_div_x727',
#  'x584',
#  'x732',
#  'x335',
#  'x558',
#  'x511',
#  'x827',
#  'x389',
#  'x21',
#  'x735',
#  'x354',
#  'x186_div_x419',
#  'x628',
#  'x600_div_x821',
#  'x708',
#  'x671',
#  'x430',
#  'x649',
#  'x928',
#  'x548',
#  'x932',
#  'x814',
#  'x209',
#  'x325',
#  'x285',
#  'x162',
#  'x106']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.3, shuffle=True, stratify=y)

# %%
rfc = RandomForestClassifier(random_state=seed)
rfc.fit(X_train, y_train)

cat = CatBoostClassifier(use_best_model=True, random_state=seed, verbose=500)
cat.fit(X_train, y_train, eval_set=(X_test, y_test))

xgb = XGBClassifier(random_state=seed)
xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=10)

lgbm = LGBMClassifier(random_state=seed, verbose=-1)
lgbm.fit(X_train, y_train, eval_set=[(X_test, y_test)])
# Out:
# Learning rate set to 0.060814
# 0:	learn: 0.6427362	test: 0.6431619	best: 0.6431619 (0)	total: 32.6ms	remaining: 32.5s
# 500:	learn: 0.1262870	test: 0.2199556	best: 0.2199556 (500)	total: 13.5s	remaining: 13.4s
# 999:	learn: 0.0739787	test: 0.2187448	best: 0.2184275 (800)	total: 25.8s	remaining: 0us
#
# bestTest = 0.2184275354
# bestIteration = 800
#
# Shrink model to first 801 iterations.
# [0]	validation_0-logloss:0.47103
# [10]	validation_0-logloss:0.25005
# [20]	validation_0-logloss:0.23771
# [30]	validation_0-logloss:0.23782
# [40]	validation_0-logloss:0.23808
# [50]	validation_0-logloss:0.23954
# [60]	validation_0-logloss:0.24375
# [70]	validation_0-logloss:0.24773
# [80]	validation_0-logloss:0.25178
# [90]	validation_0-logloss:0.25327
# [99]	validation_0-logloss:0.25701
# LGBMClassifier(random_state=22, verbose=-1)

# %%
print(f1_score(y_test, rfc.predict(X_test)))
print(f1_score(y_test, cat.predict(X_test)))
print(f1_score(y_test, xgb.predict(X_test)))
print(f1_score(y_test, lgbm.predict(X_test)))
# Out:
# 0.8579846788450206
# 0.8722974920726434
# 0.8589558696279204
# 0.869942196531792

# %%
cat_new = CatBoostClassifier(
# 226:	learn: 0.8999653	total: 16s	remaining: 1m 29s
# 227:	learn: 0.8999653	total: 16.1s	remaining: 1m 29s
# 228:	learn: 0.8999653	total: 16.2s	remaining: 1m 29s
# 229:	learn: 0.8999653	total: 16.3s	remaining: 1m 29s
# 230:	learn: 0.8997916	total: 16.3s	remaining: 1m 29s
# 231:	learn: 0.8999826	total: 16.4s	remaining: 1m 29s
# 232:	learn: 0.8999826	total: 16.5s	remaining: 1m 29s
# 233:	learn: 0.9003299	total: 16.6s	remaining: 1m 29s
# 234:	learn: 0.9007037	total: 16.7s	remaining: 1m 29s
# 235:	learn: 0.9007037	total: 16.8s	remaining: 1m 29s
# 236:	learn: 0.9007037	total: 16.8s	remaining: 1m 29s
# 237:	learn: 0.9013375	total: 16.9s	remaining: 1m 29s
# 238:	learn: 0.9013375	total: 17s	remaining: 1m 29s
# 239:	learn: 0.9012592	total: 17.1s	remaining: 1m 29s
# 240:	learn: 0.9013375	total: 17.2s	remaining: 1m 30s
# 241:	learn: 0.9016507	total: 17.3s	remaining: 1m 30s
# 242:	learn: 0.9016507	total: 17.4s	remaining: 1m 30s
# 243:	learn: 0.9015112	total: 17.5s	remaining: 1m 30s
# 244:	learn: 0.9015112	total: 17.6s	remaining: 1m 29s
# 245:	learn: 0.9015112	total: 17.6s	remaining: 1m 29s
# 246:	learn: 0.9018416	total: 17.7s	remaining: 1m 29s
# 247:	learn: 0.9018416	total: 17.8s	remaining: 1m 29s
# 248:	learn: 0.9019710	total: 17.9s	remaining: 1m 29s
# 249:	learn: 0.9018927	total: 18s	remaining: 1m 29s
# 250:	learn: 0.9024920	total: 18s	remaining: 1m 29s
# 251:	learn: 0.9024750	total: 18.1s	remaining: 1m 29s
# 252:	learn: 0.9023353	total: 18.2s	remaining: 1m 29s
# 253:	learn: 0.9029961	total: 18.3s	remaining: 1m 29s
# 254:	learn: 0.9029961	total: 18.4s	remaining: 1m 29s
# 255:	learn: 0.9029961	total: 18.4s	remaining: 1m 29s
# 256:	learn: 0.9029961	total: 18.5s	remaining: 1m 29s
# 257:	learn: 0.9029961	total: 18.6s	remaining: 1m 29s
# 258:	learn: 0.9029177	total: 18.7s	remaining: 1m 29s
# 259:	learn: 0.9029177	total: 18.8s	remaining: 1m 29s
# 260:	learn: 0.9029177	total: 18.9s	remaining: 1m 29s
# 261:	learn: 0.9027609	total: 19s	remaining: 1m 29s
# 262:	learn: 0.9027609	total: 19s	remaining: 1m 29s
# 263:	learn: 0.9027609	total: 19.1s	remaining: 1m 29s
# 264:	learn: 0.9027609	total: 19.2s	remaining: 1m 29s
# 265:	learn: 0.9027609	total: 19.3s	remaining: 1m 29s
# 266:	learn: 0.9033603	total: 19.3s	remaining: 1m 29s
# 267:	learn: 0.9033603	total: 19.4s	remaining: 1m 29s
# 268:	learn: 0.9033603	total: 19.5s	remaining: 1m 29s
# 269:	learn: 0.9036458	total: 19.6s	remaining: 1m 29s
# 270:	learn: 0.9039764	total: 19.7s	remaining: 1m 29s
# 271:	learn: 0.9039764	total: 19.7s	remaining: 1m 29s
# 547:	learn: 0.9316017	total: 39.4s	remaining: 1m 8s
# 548:	learn: 0.9317631	total: 39.5s	remaining: 1m 8s
# 549:	learn: 0.9318556	total: 39.5s	remaining: 1m 8s
# 550:	learn: 0.9318556	total: 39.6s	remaining: 1m 8s
# 551:	learn: 0.9319363	total: 39.7s	remaining: 1m 8s
# 552:	learn: 0.9319363	total: 39.7s	remaining: 1m 8s
# 553:	learn: 0.9322019	total: 39.8s	remaining: 1m 7s
# 554:	learn: 0.9321095	total: 39.9s	remaining: 1m 7s
# 555:	learn: 0.9325366	total: 39.9s	remaining: 1m 7s
# 556:	learn: 0.9323751	total: 40s	remaining: 1m 7s
# 557:	learn: 0.9323751	total: 40.1s	remaining: 1m 7s
# 558:	learn: 0.9323751	total: 40.1s	remaining: 1m 7s
# 559:	learn: 0.9326174	total: 40.2s	remaining: 1m 7s
# 560:	learn: 0.9326174	total: 40.3s	remaining: 1m 7s
# 561:	learn: 0.9326174	total: 40.3s	remaining: 1m 7s
# 562:	learn: 0.9326865	total: 40.4s	remaining: 1m 7s
# 563:	learn: 0.9326865	total: 40.4s	remaining: 1m 7s
# 564:	learn: 0.9327556	total: 40.5s	remaining: 1m 7s
# 565:	learn: 0.9331254	total: 40.6s	remaining: 1m 6s
# 566:	learn: 0.9331254	total: 40.6s	remaining: 1m 6s
# 567:	learn: 0.9332178	total: 40.7s	remaining: 1m 6s
# 568:	learn: 0.9332294	total: 40.8s	remaining: 1m 6s
# 569:	learn: 0.9336567	total: 40.9s	remaining: 1m 6s
# 570:	learn: 0.9336567	total: 40.9s	remaining: 1m 6s
# 571:	learn: 0.9336567	total: 41s	remaining: 1m 6s
# 572:	learn: 0.9339222	total: 41.1s	remaining: 1m 6s
# 573:	learn: 0.9338299	total: 41.1s	remaining: 1m 6s
# 574:	learn: 0.9338299	total: 41.2s	remaining: 1m 6s
# 575:	learn: 0.9335413	total: 41.3s	remaining: 1m 6s
# 576:	learn: 0.9337261	total: 41.3s	remaining: 1m 6s
# 577:	learn: 0.9337261	total: 41.4s	remaining: 1m 6s
# 578:	learn: 0.9337261	total: 41.5s	remaining: 1m 5s
# 579:	learn: 0.9337261	total: 41.6s	remaining: 1m 5s
# 580:	learn: 0.9339917	total: 41.6s	remaining: 1m 5s
# 581:	learn: 0.9339917	total: 41.7s	remaining: 1m 5s
# 582:	learn: 0.9342459	total: 41.8s	remaining: 1m 5s
# 583:	learn: 0.9343382	total: 41.8s	remaining: 1m 5s
# 584:	learn: 0.9340840	total: 41.9s	remaining: 1m 5s
# 585:	learn: 0.9339917	total: 42s	remaining: 1m 5s
# 586:	learn: 0.9339917	total: 42s	remaining: 1m 5s
# 587:	learn: 0.9339917	total: 42.1s	remaining: 1m 5s
# 588:	learn: 0.9342459	total: 42.2s	remaining: 1m 5s
# 589:	learn: 0.9342459	total: 42.2s	remaining: 1m 5s
# 590:	learn: 0.9342459	total: 42.3s	remaining: 1m 5s
# 591:	learn: 0.9342459	total: 42.4s	remaining: 1m 4s
# 592:	learn: 0.9346151	total: 42.4s	remaining: 1m 4s
# 878:	learn: 0.9514111	total: 1m 1s	remaining: 43.2s
# 879:	learn: 0.9514111	total: 1m 1s	remaining: 43.1s
# 880:	learn: 0.9514111	total: 1m 1s	remaining: 43s
# 881:	learn: 0.9514111	total: 1m 1s	remaining: 43s
# 882:	learn: 0.9515920	total: 1m 1s	remaining: 42.9s
# 883:	learn: 0.9516825	total: 1m 1s	remaining: 42.8s
# 884:	learn: 0.9516908	total: 1m 1s	remaining: 42.8s
# 885:	learn: 0.9516908	total: 1m 1s	remaining: 42.7s
# 886:	learn: 0.9517729	total: 1m 1s	remaining: 42.6s
# 887:	learn: 0.9517729	total: 1m 1s	remaining: 42.5s
# 888:	learn: 0.9518550	total: 1m 1s	remaining: 42.5s
# 889:	learn: 0.9518550	total: 1m 1s	remaining: 42.4s
# 890:	learn: 0.9518550	total: 1m 1s	remaining: 42.3s
# 891:	learn: 0.9519372	total: 1m 1s	remaining: 42.3s
# 892:	learn: 0.9519372	total: 1m 2s	remaining: 42.2s
# 893:	learn: 0.9519372	total: 1m 2s	remaining: 42.1s
# 894:	learn: 0.9519372	total: 1m 2s	remaining: 42s
# 895:	learn: 0.9519372	total: 1m 2s	remaining: 42s
# 896:	learn: 0.9519372	total: 1m 2s	remaining: 41.9s
# 897:	learn: 0.9519372	total: 1m 2s	remaining: 41.8s
# 898:	learn: 0.9521180	total: 1m 2s	remaining: 41.8s
# 899:	learn: 0.9522002	total: 1m 2s	remaining: 41.7s
# 900:	learn: 0.9521180	total: 1m 2s	remaining: 41.6s
# 901:	learn: 0.9522084	total: 1m 2s	remaining: 41.6s
# 902:	learn: 0.9522084	total: 1m 2s	remaining: 41.5s
# 903:	learn: 0.9522084	total: 1m 2s	remaining: 41.4s
# 904:	learn: 0.9522084	total: 1m 2s	remaining: 41.3s
# 905:	learn: 0.9522084	total: 1m 2s	remaining: 41.3s
# 906:	learn: 0.9522084	total: 1m 2s	remaining: 41.2s
# 907:	learn: 0.9522084	total: 1m 3s	remaining: 41.1s
# 908:	learn: 0.9522084	total: 1m 3s	remaining: 41s
# 909:	learn: 0.9524713	total: 1m 3s	remaining: 41s
# 910:	learn: 0.9523727	total: 1m 3s	remaining: 40.9s
# 911:	learn: 0.9524549	total: 1m 3s	remaining: 40.8s
# 912:	learn: 0.9525453	total: 1m 3s	remaining: 40.7s
# 913:	learn: 0.9526275	total: 1m 3s	remaining: 40.7s
# 914:	learn: 0.9528082	total: 1m 3s	remaining: 40.6s
# 915:	learn: 0.9528082	total: 1m 3s	remaining: 40.5s
# 916:	learn: 0.9531533	total: 1m 3s	remaining: 40.5s
# 917:	learn: 0.9531614	total: 1m 3s	remaining: 40.4s
# 918:	learn: 0.9530711	total: 1m 3s	remaining: 40.3s
# 919:	learn: 0.9529808	total: 1m 3s	remaining: 40.2s
# 920:	learn: 0.9529808	total: 1m 3s	remaining: 40.2s
# ...
# 1203:	learn: 0.9650903	total: 1m 22s	remaining: 20.3s
# 1204:	learn: 0.9650903	total: 1m 22s	remaining: 20.2s
# 1205:	learn: 0.9653512	total: 1m 22s	remaining: 20.2s
# 1473:	learn: 0.9749614	total: 1m 40s	remaining: 1.77s
# 1474:	learn: 0.9750493	total: 1m 40s	remaining: 1.7s
# 1475:	learn: 0.9750493	total: 1m 40s	remaining: 1.63s
# 1476:	learn: 0.9752208	total: 1m 40s	remaining: 1.57s
# 1477:	learn: 0.9753044	total: 1m 40s	remaining: 1.5s
# 1478:	learn: 0.9753923	total: 1m 40s	remaining: 1.43s
# 1479:	learn: 0.9753965	total: 1m 40s	remaining: 1.36s
# 1480:	learn: 0.9753086	total: 1m 40s	remaining: 1.29s
# 1481:	learn: 0.9753086	total: 1m 40s	remaining: 1.23s
# 1482:	learn: 0.9753044	total: 1m 40s	remaining: 1.16s
# 1483:	learn: 0.9753044	total: 1m 41s	remaining: 1.09s
# 1484:	learn: 0.9753044	total: 1m 41s	remaining: 1.02s
# 1485:	learn: 0.9753044	total: 1m 41s	remaining: 953ms
# 1486:	learn: 0.9753044	total: 1m 41s	remaining: 885ms
# 1487:	learn: 0.9753044	total: 1m 41s	remaining: 817ms
# 1488:	learn: 0.9753044	total: 1m 41s	remaining: 749ms
# 1489:	learn: 0.9751286	total: 1m 41s	remaining: 681ms
# 1490:	learn: 0.9753044	total: 1m 41s	remaining: 613ms
# 1491:	learn: 0.9753923	total: 1m 41s	remaining: 545ms
# 1492:	learn: 0.9753044	total: 1m 41s	remaining: 476ms
# 1493:	learn: 0.9753923	total: 1m 41s	remaining: 408ms
# 1494:	learn: 0.9754801	total: 1m 41s	remaining: 340ms
# 1495:	learn: 0.9756516	total: 1m 41s	remaining: 272ms
# 1496:	learn: 0.9757394	total: 1m 41s	remaining: 204ms
# 1497:	learn: 0.9758272	total: 1m 41s	remaining: 136ms
# 1498:	learn: 0.9758272	total: 1m 42s	remaining: 68ms
# 1499:	learn: 0.9758272	total: 1m 42s	remaining: 0us

# %%
test = pd.read_csv("test.tsv", sep='\t', index_col=0)
test = test.replace('?', np.nan)
test = imp.transform(test)

# %%
test = test.astype(float)

# %%
for x in crs_late[abs(crs_late) > 0.3].index.tolist():
    for x2 in crs_late[abs(crs_late) > 0.3].index.tolist():
        if x != x2:
            test[f'{x}_div_{x2}'] = test[x] / test[x2]

# %%
prediction = cat_new.predict(test[final_cols])

# %%
submission = pd.read_csv("test.tsv", sep='\t')[["id"]].copy()

# %%
submission
# Out:
#           id
# 0      20001
# 1      20002
# 2      20003
# 3      20004
# 4      20005
# ...      ...
# 12340  32341
# 12341  32342
# 12342  32343
# 12343  32344
# 12344  32345
#
# [12345 rows x 1 columns]

# %%
submission["y"] = prediction

# %%
submission["y"].value_counts()
# Out:
# y
# 0    8885
# 1    3460
# Name: count, dtype: int64

# %%
submission['y'] = submission['y'].map(dct_out)

# %%
submission.to_csv("submission.tsv", sep='\t')

# %%
submission
# Out:
#           id  y
# 0      20001  P
# 1      20002  N
# 2      20003  N
# 3      20004  N
# 4      20005  N
# ...      ... ..
# 12340  32341  N
# 12341  32342  N
# 12342  32343  N
# 12343  32344  N
# 12344  32345  N
#
# [12345 rows x 2 columns]
