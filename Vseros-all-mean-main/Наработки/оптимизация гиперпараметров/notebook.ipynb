# %%
import optuna

import numpy as np
import pandas as pd

from catboost import CatBoostClassifier
from sklearn.model_selection import KFold, train_test_split
import seaborn as sns
from sklearn.metrics import f1_score
import warnings 

warnings.simplefilter('ignore')

# %%
df = sns.load_dataset('penguins')

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
targets = ['sex']
cat_features = ['species', 'island']
filtered_features = [i for i in df.columns if i not in targets]

# %%
def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    param = {
        'iterations' : 400,
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.05),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8),
        
        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced", "None"]),
        "depth": trial.suggest_int("depth", 3, 9),
        
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "used_ram_limit": "14gb",
        "eval_metric": "Accuracy", 
    }

    
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)
        
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        

    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=22,
        cat_features=cat_features,
    )

    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=0,
        plot=False,
        early_stopping_rounds=5,
    )

    y_pred = clf.predict(X_val)
    return clf, y_pred

# %%
def objective(trial, return_models=False):
    n_splits = 3
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    X_train = df[filtered_features].drop(targets, axis=1, errors="ignore")
    y_train = df[targets]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X_train):
        train_data = X_train.iloc[train_idx, :], y_train.iloc[train_idx]
        valid_data = X_train.iloc[valid_idx, :], y_train.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
        scores.append(f1_score(y_pred, valid_data[1], average="binary", pos_label="Male"))
        models.append(model)
        break
         

    result = np.mean(scores)
    
    if return_models:
        return result, models
    else:
        return result

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective,
               n_trials=600,
               show_progress_bar=True,)

# %%
study.best_trial.value
# Out:
# 0.9464285714285714

# %%
study.best_trial.params
# Out:
# {'learning_rate': 0.048772277009571235,
#  'l2_leaf_reg': 24,
#  'colsample_bylevel': 0.6363723336164767,
#  'auto_class_weights': 'None',
#  'depth': 8,
#  'boosting_type': 'Ordered',
#  'bootstrap_type': 'Bayesian',
#  'bagging_temperature': 6.481080893132568}

# %%
valid_scores, models = objective(
    optuna.trial.FixedTrial(study.best_params),
    return_models=True,
)

# %%
model = models[0]

# %%
from optuna_integration import CatBoostPruningCallback

# %%
def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    param = {
        'iterations' : 400,
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.05),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8),
        
        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced", "None"]),
        "depth": trial.suggest_int("depth", 3, 9),
        
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "used_ram_limit": "14gb",
        "eval_metric": "Accuracy", 
    }

    
    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)
        
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)
        

    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=22,
        cat_features=cat_features,
    )
    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=0,
        plot=False,
        early_stopping_rounds=5,
        callbacks=[pruning_callback],
    )
    pruning_callback.check_pruned()
    y_pred = clf.predict(X_val)
    return clf, y_pred

# %%
def objective(trial, return_models=False):
    n_splits = 3
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    X_train = df[filtered_features].drop(targets, axis=1, errors="ignore")
    y_train = df[targets]

    scores, models = [], []
    
    for train_idx, valid_idx in kf.split(X_train):
        train_data = X_train.iloc[train_idx, :], y_train.iloc[train_idx]
        valid_data = X_train.iloc[valid_idx, :], y_train.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
        scores.append(f1_score(y_pred, valid_data[1], average="binary", pos_label="Male"))
        models.append(model)
        break
         

    result = np.mean(scores)
    
    if return_models:
        return result, models
    else:
        return result

# %%
study = optuna.create_study(
     pruner=optuna.pruners.MedianPruner(n_warmup_steps=5),
     direction="maximize",
 )

study.optimize(objective,
                n_trials=1000,
                n_jobs = -1,
               )
# Out:
# [I 2024-08-07 16:08:17,259] A new study created in memory with name: no-name-266a2e31-2a35-43f6-ad76-4e012f942fa6
# [I 2024-08-07 16:08:17,546] Trial 1 finished with value: 0.8739495798319328 and parameters: {'learning_rate': 0.020036204367077495, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.2621996203626756, 'auto_class_weights': 'None', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.8739495798319328.
# [I 2024-08-07 16:08:17,554] Trial 6 finished with value: 0.85 and parameters: {'learning_rate': 0.04694927039853952, 'l2_leaf_reg': 13, 'colsample_bylevel': 0.05655485951573276, 'auto_class_weights': 'Balanced', 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.8739495798319328.
# [I 2024-08-07 16:08:17,737] Trial 7 finished with value: 0.875 and parameters: {'learning_rate': 0.04656021344250694, 'l2_leaf_reg': 14, 'colsample_bylevel': 0.5721123057963309, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.6043111187117076}. Best is trial 7 with value: 0.875.
# [I 2024-08-07 16:08:17,749] Trial 3 finished with value: 0.8833333333333333 and parameters: {'learning_rate': 0.0014271402398253284, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.7825021067135164, 'auto_class_weights': 'SqrtBalanced', 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3722797728159859}. Best is trial 3 with value: 0.8833333333333333.
# [I 2024-08-07 16:08:17,875] Trial 9 finished with value: 0.9230769230769231 and parameters: {'learning_rate': 0.011015918755453918, 'l2_leaf_reg': 16, 'colsample_bylevel': 0.506897344037951, 'auto_class_weights': 'SqrtBalanced', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:17,883] Trial 8 finished with value: 0.8888888888888888 and parameters: {'learning_rate': 0.007012079446350097, 'l2_leaf_reg': 30, 'colsample_bylevel': 0.6415794732707905, 'auto_class_weights': 'Balanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.776135823098381}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:17,952] Trial 10 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:17,984] Trial 11 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:17,994] Trial 4 finished with value: 0.896551724137931 and parameters: {'learning_rate': 0.023613414158614492, 'l2_leaf_reg': 25, 'colsample_bylevel': 0.4557820423270689, 'auto_class_weights': 'Balanced', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:18,014] Trial 2 finished with value: 0.896551724137931 and parameters: {'learning_rate': 0.0065427401483644995, 'l2_leaf_reg': 36, 'colsample_bylevel': 0.6081969082293044, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.1947596643491406}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:18,021] Trial 0 finished with value: 0.905982905982906 and parameters: {'learning_rate': 0.01597456316930968, 'l2_leaf_reg': 35, 'colsample_bylevel': 0.5258321827211759, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:18,145] Trial 14 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:18,156] Trial 5 finished with value: 0.896551724137931 and parameters: {'learning_rate': 0.017072625157645255, 'l2_leaf_reg': 42, 'colsample_bylevel': 0.5582161401729316, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.053245786485503}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:18,340] Trial 12 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:18,521] Trial 13 finished with value: 0.8925619834710744 and parameters: {'learning_rate': 0.042690591519308096, 'l2_leaf_reg': 30, 'colsample_bylevel': 0.7011212095424002, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5444035946822349}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:18,531] Trial 16 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:18,571] Trial 18 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:18,571] Trial 17 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:18,674] Trial 15 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:18,723] Trial 19 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:18,820] Trial 25 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:18,844] Trial 23 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:18,891] Trial 20 finished with value: 0.8983050847457628 and parameters: {'learning_rate': 0.03565188612794496, 'l2_leaf_reg': 3, 'colsample_bylevel': 0.4106568849014389, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:18,923] Trial 26 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:18,960] Trial 22 finished with value: 0.9 and parameters: {'learning_rate': 0.030537293465242334, 'l2_leaf_reg': 8, 'colsample_bylevel': 0.4149163534111563, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,144] Trial 28 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:19,190] Trial 29 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:19,195] Trial 24 finished with value: 0.9043478260869565 and parameters: {'learning_rate': 0.015227850585246387, 'l2_leaf_reg': 38, 'colsample_bylevel': 0.5086311033722215, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,202] Trial 21 finished with value: 0.896551724137931 and parameters: {'learning_rate': 0.033707320949965994, 'l2_leaf_reg': 2, 'colsample_bylevel': 0.39672517648734434, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,204] Trial 27 finished with value: 0.9 and parameters: {'learning_rate': 0.014571857112307934, 'l2_leaf_reg': 50, 'colsample_bylevel': 0.5197837069479276, 'auto_class_weights': 'None', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,401] Trial 32 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:19,501] Trial 35 finished with value: 0.8869565217391304 and parameters: {'learning_rate': 0.02092542613162895, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.7416933502551879, 'auto_class_weights': 'None', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,524] Trial 33 finished with value: 0.9230769230769231 and parameters: {'learning_rate': 0.027785742637428102, 'l2_leaf_reg': 11, 'colsample_bylevel': 0.502402587376418, 'auto_class_weights': 'None', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,534] Trial 34 finished with value: 0.8869565217391304 and parameters: {'learning_rate': 0.019339914933763715, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.747309147027434, 'auto_class_weights': 'None', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,580] Trial 36 finished with value: 0.8813559322033898 and parameters: {'learning_rate': 0.018287399269577197, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.490535822978114, 'auto_class_weights': 'None', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,598] Trial 37 finished with value: 0.8703703703703703 and parameters: {'learning_rate': 0.019764138018412362, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.7363855178631005, 'auto_class_weights': 'None', 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,651] Trial 30 finished with value: 0.8888888888888888 and parameters: {'learning_rate': 0.020115334044304496, 'l2_leaf_reg': 13, 'colsample_bylevel': 0.5278106002643336, 'auto_class_weights': 'None', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,667] Trial 38 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:19,735] Trial 31 finished with value: 0.8947368421052632 and parameters: {'learning_rate': 0.027992649993829263, 'l2_leaf_reg': 10, 'colsample_bylevel': 0.5149673008189252, 'auto_class_weights': 'None', 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,917] Trial 43 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:19,954] Trial 39 pruned. Trial was pruned at iteration 6.
# [I 2024-08-07 16:08:19,956] Trial 41 finished with value: 0.8703703703703703 and parameters: {'learning_rate': 0.027503197313986295, 'l2_leaf_reg': 40, 'colsample_bylevel': 0.5978097171372541, 'auto_class_weights': 'None', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:19,964] Trial 40 finished with value: 0.9137931034482759 and parameters: {'learning_rate': 0.026996305582184212, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.48008516437782356, 'auto_class_weights': 'None', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,011] Trial 42 finished with value: 0.8909090909090909 and parameters: {'learning_rate': 0.009598761932581088, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.5937363834344237, 'auto_class_weights': 'None', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,055] Trial 45 finished with value: 0.8990825688073395 and parameters: {'learning_rate': 0.02844235264905661, 'l2_leaf_reg': 40, 'colsample_bylevel': 0.5912299489908588, 'auto_class_weights': 'Balanced', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,077] Trial 46 finished with value: 0.8909090909090909 and parameters: {'learning_rate': 0.009567486822969692, 'l2_leaf_reg': 43, 'colsample_bylevel': 0.5916094607730017, 'auto_class_weights': 'Balanced', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,158] Trial 44 finished with value: 0.9137931034482759 and parameters: {'learning_rate': 0.02741643400196342, 'l2_leaf_reg': 34, 'colsample_bylevel': 0.5827125067716451, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,464] Trial 47 finished with value: 0.8983050847457628 and parameters: {'learning_rate': 0.00844036593145028, 'l2_leaf_reg': 40, 'colsample_bylevel': 0.5829475469936111, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,490] Trial 50 finished with value: 0.8727272727272727 and parameters: {'learning_rate': 0.00512176894896592, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.5721041182969998, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,492] Trial 49 finished with value: 0.8727272727272727 and parameters: {'learning_rate': 0.005054616627244129, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.5749583344533352, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,516] Trial 52 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:20,556] Trial 53 finished with value: 0.8793103448275862 and parameters: {'learning_rate': 0.004440963405485163, 'l2_leaf_reg': 23, 'colsample_bylevel': 0.6677984549119735, 'auto_class_weights': 'Balanced', 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,564] Trial 48 finished with value: 0.8813559322033898 and parameters: {'learning_rate': 0.02365795016531678, 'l2_leaf_reg': 33, 'colsample_bylevel': 0.5616212369383806, 'auto_class_weights': 'Balanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,579] Trial 54 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:20,598] Trial 51 finished with value: 0.8869565217391304 and parameters: {'learning_rate': 0.00514537116165153, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.6444197977510638, 'auto_class_weights': 'Balanced', 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,912] Trial 56 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:20,963] Trial 58 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:20,964] Trial 57 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:20,971] Trial 59 finished with value: 0.8771929824561403 and parameters: {'learning_rate': 0.025763561287732994, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.368688749588057, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 10.661263398053846}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:20,989] Trial 55 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:21,153] Trial 61 finished with value: 0.896551724137931 and parameters: {'learning_rate': 0.026091769091911216, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.45129890952592217, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 11.890408834411003}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:21,161] Trial 60 finished with value: 0.9 and parameters: {'learning_rate': 0.039822214684958085, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.4526540299627104, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 11.980111758708086}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:21,270] Trial 64 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:21,395] Trial 69 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:21,424] Trial 68 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:08:21,434] Trial 67 finished with value: 0.8771929824561403 and parameters: {'learning_rate': 0.037938332914295984, 'l2_leaf_reg': 36, 'colsample_bylevel': 0.4502100145511082, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 12.669581205872738}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:21,445] Trial 63 finished with value: 0.896551724137931 and parameters: {'learning_rate': 0.02622440473126824, 'l2_leaf_reg': 31, 'colsample_bylevel': 0.45078219350245613, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 12.381117672914549}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:21,520] Trial 66 finished with value: 0.8983050847457628 and parameters: {'learning_rate': 0.03852597293908108, 'l2_leaf_reg': 36, 'colsample_bylevel': 0.46586640180178696, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 11.924162964066763}. Best is trial 9 with value: 0.9230769230769231.
# [I 2024-08-07 16:08:21,540] Trial 62 finished with value: 0.9298245614035088 and parameters: {'learning_rate': 0.039122495093524695, 'l2_leaf_reg': 37, 'colsample_bylevel': 0.37535232931731505, 'auto_class_weights': 'SqrtBalanced', 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature':
pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:51,228] Trial 973 finished with value: 0.905982905982906 and parameters: {'learning_rate': 0.03207181170411839, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.45612409430623796, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.442565414416682}. Best is trial 221 with value: 0.9391304347826087.
# [I 2024-08-07 16:09:51,323] Trial 971 finished with value: 0.9401709401709402 and parameters: {'learning_rate': 0.031027905853074127, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.45528619912533536, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.5111708001218345}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:51,363] Trial 972 finished with value: 0.9310344827586207 and parameters: {'learning_rate': 0.02903628017139495, 'l2_leaf_reg': 19, 'colsample_bylevel': 0.4563576586827458, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.428941469254233}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:51,368] Trial 976 finished with value: 0.9401709401709402 and parameters: {'learning_rate': 0.02717791234884824, 'l2_leaf_reg': 15, 'colsample_bylevel': 0.4556856301387373, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.45213328674841}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:51,476] Trial 978 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,148] Trial 979 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,159] Trial 983 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,193] Trial 980 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,223] Trial 986 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,224] Trial 982 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,247] Trial 984 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:52,266] Trial 981 finished with value: 0.9243697478991597 and parameters: {'learning_rate': 0.025559456165127357, 'l2_leaf_reg': 16, 'colsample_bylevel': 0.4556241390046233, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.131541435130225}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:52,501] Trial 985 finished with value: 0.9122807017543859 and parameters: {'learning_rate': 0.026781331358844477, 'l2_leaf_reg': 15, 'colsample_bylevel': 0.4808881054156169, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.2743282809840295}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:53,142] Trial 990 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,209] Trial 989 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,283] Trial 992 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,286] Trial 993 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,287] Trial 991 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,339] Trial 994 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,448] Trial 987 finished with value: 0.9122807017543859 and parameters: {'learning_rate': 0.029289465906360522, 'l2_leaf_reg': 15, 'colsample_bylevel': 0.48110680782503973, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.338960148840339}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:53,486] Trial 988 finished with value: 0.9285714285714286 and parameters: {'learning_rate': 0.028480151354290266, 'l2_leaf_reg': 16, 'colsample_bylevel': 0.48166286374986833, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.404894759911156}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:53,873] Trial 995 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:53,914] Trial 996 pruned. Trial was pruned at iteration 5.
# [I 2024-08-07 16:09:54,031] Trial 997 finished with value: 0.9230769230769231 and parameters: {'learning_rate': 0.028339598125591236, 'l2_leaf_reg': 18, 'colsample_bylevel': 0.4538738509854865, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.8599965129171725}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:54,042] Trial 998 finished with value: 0.9322033898305084 and parameters: {'learning_rate': 0.02871260868859205, 'l2_leaf_reg': 18, 'colsample_bylevel': 0.454677697745426, 'auto_class_weights': 'None', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.8917278880189325}. Best is trial 971 with value: 0.9401709401709402.
# [I 2024-08-07 16:09:54,063] Trial 999 finished with value: 0.9230769230769231 and parameters: {'learning_rate': 0.027014092996373456, 'l2_leaf_reg': 18, 'colsample_bylevel': 0.45525516582863396, 'auto_class_weights': 'SqrtBalanced', 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.87046039716037}. Best is trial 971 with value: 0.9401709401709402.

# %%
study.best_trial.value
# Out:
# 0.9401709401709402

# %%
valid_scores, models = objective(
    optuna.trial.FixedTrial(study.best_params),
    return_models=True,
)

# %%
model = models[0]
